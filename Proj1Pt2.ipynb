# %% [markdown]
# <a href="https://colab.research.google.com/github/adh2004/Python/blob/master/Proj1Pt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import platform

print("Directory:", os.getcwd())
print("OS:", platform.system())

# %%
# !docker --version
# !docker info

# %%
from pathlib import Path

project = Path("Project1Part2")
project.mkdir(exist_ok=True, parents=True)

print("Project location", project.resolve())

# %%
app_code= """
from flask import Flask

app = Flask(__name__)

@app.route("/")
def home():
    return '''
    <h1>Local Colab Container Demo</h1>
    <p>This application is running inside a Docker container.</p>
    '''

@app.route("/health")
def health():
    return {
        "status": "healthy",
        "containerized": True
    }

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)
"""

# Assuming 'project' is defined in a previous cell as Path("Project1Part2")
from pathlib import Path
project = Path("Project1Part2")

with open(project / "app.py", "w") as f:
    f.write(app_code)

# %%
requirements = """
Flask ==3.1.2
"""

with open("Project1Part2/requirements.txt", "w") as f:
    f.write(requirements.strip())

# %%
dockerfile = """
FROM python:3.12-slim

WORKDIR /app

COPY requirements.txt .

RUN pip install --no-cache-dir -r requirements.txt

COPY app.py .

EXPOSE 5000

CMD ["python", "app.py"]
"""

with open("Project1Part2/Dockerfile", "w") as f:
    f.write(dockerfile.strip())

# %%
from pathlib import Path

project = Path("Project1Part2")

for file in project.iterdir():
    print(file.name)

# %%
# !docker build -t colab-vm-project:1.0 ./Project1Part2

# %%
# !docker images

# %%
# !docker run --name colab-vm -p 5000:5000 colab-vm-project:1.0

# %%
# !docker ps
